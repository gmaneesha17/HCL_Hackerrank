# %%
def insert(a,t):
    l=0
    h=len(a)-1
    while l<=h:
        m=(l+h)//2
        if a[m]==t:
            return m
        elif a[m]<t:
            l=m+1
        else:
            h=m-1
    return l
a=list(map(int,input().split()))
t=int(input())
print(insert(a,t))
# Out:
#  1 2 3 4 6 7
#  5
# 4
