# %%
class Node:
    def __init__(self, data):
        self.data=data
        self.next=None
def remove(head,n):
    dummy=Node(0)
    dummy.next=head
    fast=dummy
    slow=dummy
    for i in range(n+1):
        fast=fast.next
    while fast:
        fast=fast.next
        slow=slow.next
    slow.next=slow.next.next
    return dummy.next
a=list(map(int,input().split()))
n=int(input())
head=Node(a[0])
t=head
for i in range(1,len(a)):
    t.next=Node(a[i])
    t=t.next
head=remove(head,n)
cur=head
while cur:
    print(cur.data,end=" ")
    cur=cur.next
# Out:
#  1 2 3 4 5 6 7
#  2
# 1 2 3 4 5 7
